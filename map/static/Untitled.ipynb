# %%
import pandas as pd

# %%
data = pd.read_csv("cleaned_merge_final.csv")

# %%
data.head()
# Out:
#    MONTH  DAY  DAY_OF_WEEK               AIRLINE ORIGIN_AIRPORT  \
# 0      1    1            4  Alaska Airlines Inc.            ANC
# 1      1    1            4  Alaska Airlines Inc.            ANC
# 2      1    1            4  Alaska Airlines Inc.            ANC
# 3      1    1            4  Alaska Airlines Inc.            ANC
# 4      1    1            4  Alaska Airlines Inc.            ANC
#
#   DESTINATION_AIRPORT  DEPARTURE_DELAY  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0                 SEA            -11.0          -22.0         0          0
# 1                 SEA             -4.0          -14.0         0          0
# 2                 SEA              NaN            NaN         0          1
# 3                 SEA            -15.0          -35.0         0          0
# 4                 SEA            -11.0          -12.0         0          0
#
#    ...                          ORIGIN_AIRPORT_NAME  ORIGIN_CITY  \
# ...

# %%
data_short = data.iloc[0:200, : ]

# %%
data_short.head()
# Out:
#    MONTH  DAY  DAY_OF_WEEK               AIRLINE ORIGIN_AIRPORT  \
# 0      1    1            4  Alaska Airlines Inc.            ANC
# 1      1    1            4  Alaska Airlines Inc.            ANC
# 2      1    1            4  Alaska Airlines Inc.            ANC
# 3      1    1            4  Alaska Airlines Inc.            ANC
# 4      1    1            4  Alaska Airlines Inc.            ANC
#
#   DESTINATION_AIRPORT  DEPARTURE_DELAY  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0                 SEA            -11.0          -22.0         0          0
# 1                 SEA             -4.0          -14.0         0          0
# 2                 SEA              NaN            NaN         0          1
# 3                 SEA            -15.0          -35.0         0          0
# 4                 SEA            -11.0          -12.0         0          0
#
#    ...                          ORIGIN_AIRPORT_NAME  ORIGIN_CITY  \
# ...

# %%
len(data_short)
# Out:
# 200

# %%
data_short.to_csv("test_flight.csv")

# %%
grouped_by_origin = data.groupby("ORIGIN_AIRPORT_NAME")

# %%
grouped_by_origin.head()
# Out:
#          MONTH  DAY  DAY_OF_WEEK                 AIRLINE ORIGIN_AIRPORT  \
# 0            1    1            4    Alaska Airlines Inc.            ANC
# 1            1    1            4    Alaska Airlines Inc.            ANC
# 2            1    1            4    Alaska Airlines Inc.            ANC
# 3            1    1            4    Alaska Airlines Inc.            ANC
# 4            1    1            4    Alaska Airlines Inc.            ANC
# 6870         1    1            4    Alaska Airlines Inc.            FAI
# 6871         1    1            4    Alaska Airlines Inc.            FAI
# 6872         1    1            4    Alaska Airlines Inc.            FAI
# 6873         1    2            5    Alaska Airlines Inc.            FAI
# 6874         1    2            5    Alaska Airlines Inc.            FAI
# 8301         1    1            4    Alaska Airlines Inc.            GEG
# 8302         1    1            4    Alaska Airlines Inc.            GEG
# ...

# %%
origin_destination = data.groupby(['ORIGIN_AIRPORT_NAME', 'DESTINATION_AIRPORT_NAME'])

# %%
print(origin_destination)

# %%
len(grouped_by_origin)
# Out:
# 322

# %%
len(origin_destination)
# Out:
# 4696

# %%
destination_data = pd.read_csv("destination_flight_summary_data.csv") 
destination_data.head()
# Out:
#    id destination_airport             destination_airport_name  \
# 0   1                 ABE  Lehigh Valley International Airport
# 1   2                 ABI             Abilene Regional Airport
# 2   3                 ABQ    Albuquerque International Sunport
# 3   4                 ABR            Aberdeen Regional Airport
# 4   5                 ABY   Southwest Georgia Regional Airport
#
#   destination_city destination_state  destination_latitude  \
# 0        Allentown                PA              40.65236
# 1          Abilene                TX              32.41132
# 2      Albuquerque                NM              35.04022
# 3         Aberdeen                SD              45.44906
# 4           Albany                GA              31.53552
#
#    destination_longitude  mean_departure_delay  flight_count  \
# 0              -75.44040              8.216545          2514
# 1              -99.68190              7.801728          2528
# ...

# %%
print(destination_data)
# Out:
#       id destination_airport  \
# 0      1                 ABE
# 1      2                 ABI
# 2      3                 ABQ
# 3      4                 ABR
# 4      5                 ABY
# 5      6                 ACK
# 6      7                 ACT
# 7      8                 ACV
# 8      9                 ACY
# 9     10                 ADK
# 10    11                 ADQ
# 11    12                 AEX
# 12    13                 AGS
# 13    14                 AKN
# 14    15                 ALB
# 15    16                 ALO
# 16    17                 AMA
# 17    18                 ANC
# 18    19                 APN
# 19    20                 ASE
# 20    21                 ATL
# 21    22                 ATW
# 22    23                 AUS
# 23    24                 AVL
# 24    25                 AVP
# 25    26                 AZO
# 26    27                 BDL
# 27    28                 BET
# 28    29                 BFL
# 29    30                 BGM
# ..   ...                 ...
# ...

# %%
destination_data['flight_count_delay_ratio'].min()
# Out:
# -136358.1443661972
